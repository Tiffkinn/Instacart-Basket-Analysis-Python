# %% [markdown]
# # Products Data Set - Additional Cleaning

# %% [markdown]
# In this script, I will conduct some further analysis and cleaning of the products data set
#
# Note - missing values and duplicate rows have already been addressed

# %%
# Import libraries

import pandas as pd
import numpy as np
import os

# %%
# Set path

path = r"C:\Users\tiffk\Instacart Basket Analysis 22-05-2024"

# %%
# Import products dataframe

df_prods = pd.read_csv(os.path.join(path, "02 Data", "Prepared Data", "products_checked.csv"), index_col = False)

# %%
# Begin with quick view of df

df_prods
# Out:
#        Unnamed: 0  product_id  \
# 0               0           1
# 1               1           2
# 2               2           3
# 3               3           4
# 4               4           5
# ...           ...         ...
# 49667       49688       49684
# 49668       49689       49685
# 49669       49690       49686
# 49670       49691       49687
# 49671       49692       49688
#
#                                             product_name  aisle_id  \
# 0                             Chocolate Sandwich Cookies        61
# 1                                       All-Seasons Salt       104
# 2                   Robust Golden Unsweetened Oolong Tea        94
# 3      Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4                              Green Chile Anytime Sauce         5
# ...                                                  ...       ...
# 49667          Vodka, Triple Distilled, Twist of Vanilla       124
# 49668                 En Croute Roast Hazelnut Cranberry        42
# 49669                                   Artisan Baguette       112
# 49670         Smartblend Healthy Metabolism Dry Cat Food        41
# 49671                             Fresh Foaming Cleanser        73
#
#        department_id  prices
# 0                 19     5.8
# 1                 13     9.3
# 2                  7     4.5
# 3                  1    10.5
# 4                 13     4.3
# ...              ...     ...
# 49667              5     5.3
# 49668              1     3.1
# 49669              3     7.8
# 49670              8     4.7
# 49671             11    13.5
#
# [49672 rows x 6 columns]

# %%
# Remove "Unnamed: 0" column

df_prods = df_prods.drop("Unnamed: 0", axis = 1)

# %%
# Check

df_prods
# Out:
#        product_id                                       product_name  \
# 0               1                         Chocolate Sandwich Cookies
# 1               2                                   All-Seasons Salt
# 2               3               Robust Golden Unsweetened Oolong Tea
# 3               4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4               5                          Green Chile Anytime Sauce
# ...           ...                                                ...
# 49667       49684          Vodka, Triple Distilled, Twist of Vanilla
# 49668       49685                 En Croute Roast Hazelnut Cranberry
# 49669       49686                                   Artisan Baguette
# 49670       49687         Smartblend Healthy Metabolism Dry Cat Food
# 49671       49688                             Fresh Foaming Cleanser
#
#        aisle_id  department_id  prices
# 0            61             19     5.8
# 1           104             13     9.3
# 2            94              7     4.5
# 3            38              1    10.5
# 4             5             13     4.3
# ...         ...            ...     ...
# 49667       124              5     5.3
# 49668        42              1     3.1
# 49669       112              3     7.8
# 49670        41              8     4.7
# 49671        73             11    13.5
#
# [49672 rows x 5 columns]

# %% [markdown]
# Could potentially address the product_id column given the mismatch with the index column, but this does not seem essential to the analysis. Instacart may also prefer to leave the gaps for whatever reason.
#
# Focus will now be turned to the max and min values

# %%
df_prods.describe()
# Out:
#          product_id      aisle_id  department_id        prices
# count  49672.000000  49672.000000   49672.000000  49672.000000
# mean   24850.349775     67.762442      11.728942      9.993282
# std    14340.705287     38.315784       5.850779    453.615536
# min        1.000000      1.000000       1.000000      1.000000
# 25%    12432.750000     35.000000       7.000000      4.100000
# 50%    24850.500000     69.000000      13.000000      7.100000
# 75%    37268.250000    100.000000      17.000000     11.100000
# max    49688.000000    134.000000      21.000000  99999.000000

# %% [markdown]
# There is most certainly an issue with the max value in prices - Should investigate the most expensive products in this column

# %%
df_prods_sorted = df_prods.sort_values(by = "prices", ascending = False)

# %%
df_prods_sorted
# Out:
#        product_id                      product_name  aisle_id  department_id  \
# 33649       33664             2 % Reduced Fat  Milk        84             16
# 21538       21553  Lowfat 2% Milkfat Cottage Cheese       108             16
# 19376       19391         Turkey Breast Tenderloins        49             12
# 25564       25579     Naturally Smoked Trout Fillet        15             12
# 40469       40486                   Chicken Tenders        49             12
# ...           ...                               ...       ...            ...
# 11292       11307                  Goat Cheese Logs         2             16
# 32788       32803                 Regular Deodorant        80             11
# 46606       46623                   Pie Pans, Large        10             17
# 37022       37037                       Redseedless        24              4
# 21448       21463      Vanilla Bean Light Ice Cream        37              1
#
#         prices
# 33649  99999.0
# 21538  14900.0
# 19376     25.0
# 25564     25.0
# 40469     25.0
# ...        ...
# 11292      1.0
# 32788      1.0
# 46606      1.0
# 37022      1.0
# 21448      1.0
#
# [49672 rows x 5 columns]

# %%
# It is quite clear that both of the top priced items are some type of error which should be removed
# Ideally, the true price could be found out by asking someone at Instacart (like department 16)

# %%
df_prods_clean = df_prods[df_prods["prices"] < 14900]

# %%
# Check

df_prods_clean.sort_values(by = "prices", ascending = False)
# Out:
#        product_id                            product_name  aisle_id  \
# 19376       19391               Turkey Breast Tenderloins        49
# 40469       40486                         Chicken Tenders        49
# 9005         9020        Boneless Skinless Chicken Thighs        35
# 25564       25579           Naturally Smoked Trout Fillet        15
# 21452       21467                  Wild Caught Raw Shrimp        15
# ...           ...                                     ...       ...
# 4860         4875                      Buffalo Wing Sauce         5
# 20948       20963  1 Step-1 Minute Noodles Toasted Sesame        66
# 46570       46587                  Pearl Couscous Natural        63
# 48155       48172       Culture Club Kombucha Goji Ginger        31
# 21448       21463            Vanilla Bean Light Ice Cream        37
#
#        department_id  prices
# 19376             12    25.0
# 40469             12    25.0
# 9005              12    25.0
# 25564             12    25.0
# 21452             12    25.0
# ...              ...     ...
# 4860              13     1.0
# 20948              6     1.0
# 46570              9     1.0
# 48155              7     1.0
# 21448              1     1.0
#
# [49670 rows x 5 columns]

# %% [markdown]
# Outliers have been removed and the data set is ready to be exported

# %%
df_prods_clean.to_csv(os.path.join(path, "02 Data", "Prepared Data", "products_checked_v2.csv"))
